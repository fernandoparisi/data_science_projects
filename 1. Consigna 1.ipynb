# %% [markdown]
# # Consigna #1:

# %% [markdown]
# ## 1.- BBDD consultas básicas
#
#
#
# 1. Conectar, al menos, **una** de las BBDD que se les han compartido <font color='red'>netflix.db</font> o <scan><font color='red'>netflix.sql</font></scan>. (esta decisión la tomarás de acuerdo al entorno de trabajo por el que hayas optado).
#
# 2. Construir y completar una tabla como el siguiente modelo. Los textos en <font color='blue'>azul</font> debes sustuirlos por los que correspondan, según la BBDD que seleccionaste:
# <center>
# <table>
#     <tr>
#         <th colspan="3", style="border: 1px solid black; padding: 0px 10px 0px 10px">Nombre de la BBDD </th>
#         <td colspan="2", style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>netflix.sql</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px">Tabla </th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px">Clave Primaria</th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px">Clave Foránea</th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px">Total de filas</th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px">Total de columnas</th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>content</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_content</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>No existe</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>12</font></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>production</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_production</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_content</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>8</font></td>
#     </tr>
# </table></center></br>
#
# 3. Construir y completar un cuadro **por cada tabla de la BBDD** según el siguiente modelo. Los textos en <font color='blue'>azul</font> debes sustuirlos por los textos que correspondan, según la BBDD que hayas seleccionado:
#
# <center>
# <table>
#     <tr>
#         <td > </td>
#         <th colspan="6", style="border: 1px solid black; padding: 0px 10px 0px 10px">Nombre de la BBDD y su tabla</th>
#         <td colspan="6", style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>netflix.content</font></td>
#     </tr>
#     <tr>
#         <td > </td>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>id_ content</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>type</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>title_ content</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>director</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>cast</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>country</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>date_ added</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>release_ year</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>rating</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>duration</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>listed_ in</font></th>
#         <th style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>description</font></th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">No_nulos</td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>6123</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>7933</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>7923</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8737</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8740</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">Vacíos</td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">Nulos</td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>2624</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>814</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>824</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>10</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>7</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>0</font></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">Distintos</td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8747</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>2</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8740</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>4487</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>7644</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>744</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>1760</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>74</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>14</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>220</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>513</font></td>
#         <td style="border: 1px solid black; padding: 0px 5px 0px 5px"><font color='blue'>8715</font></td>
#     </tr>
#
# </table></center></br>
#
# <center>
# <table>
#     <tr>
#         <td > </td>
#         <th colspan="3", style="border: 1px solid black; padding: 0px 10px 0px 10px">Nombre de la BBDD y su tabla</th>
#         <td colspan="5", style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>netflix.production</font></td>
#     </tr>
#     <tr>
#         <td > </td>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_production</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_content</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>title_production</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>genre</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>premiere</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>runtime</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>imdb_score</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>language</font></th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">No nulos</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">Vacíos</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">Nulos</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">Distintos</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>551</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>110</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>370</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>118</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>52</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>37</font></td>
#     </tr>
# </table></center></br>
#
#
# 4. Realizar las siguientes consultas sobre una sola tabla. Los nombres de las columnas deben mostrarse en español:
#     <b>A.</b>  Listar todos los registros de la tabla, visualizando las columnas type, title_content, country, rating, duration, listed_in.
#     <b>B.</b>  Mostrar todas las filas de la tabla, presentando las columnas id_content, title_production, genre, runtime, imdb_Score.
#     <b>C.</b>  Generar un listado de todas las películas en las que participe Argentina, mostrando las columnas id_content, type, title_content, director, cast, rating, duration, listed_in.
#     <b>D.</b>  Presentar un listado con las columnas id_production, title_production, genre, language, imdb_score de los registros de la tabla en las que el imdb_score sea superior a 7.5.
#     <b>E.</b>  Mostrar las columnas id_content, type, title_content, listed_in de los registros en los que el rating público general o admitido para todas las edades.
#     <b>F.</b>  Obtener una lista con las columnas id_production, title_production, genre de los registros en que duration sea menor o igual a 105 minutos pero que además tenga una duración de al menos 60 minutos.
#     <b>G.</b>  Obtener la cantidad de registros discriminando por type y rating, ordenados alfabéticamente por rating y por type.
#     <b>H.</b>  Mostrar la cantidad  de películas en los idiomas portugués, francés, alemán, italiano y español, ordenados por cantidad, de mayor a menor.
# 5. Documentar todo lo anterior en DEEPNOTE:
#     * Crea las tablas para los puntos 2 y 3.
#     * Pega los códigos de las queries del punto 4 y agrega una captura de pantalla de la ejecución en el Administrador de BBDD, que incluya la barra de tareas de tu sistema operativo.

# %% [markdown]
# ### Consultas del punto 4.

# %% [markdown]
# ### A.

# %% [markdown]
# SELECT type, title_content, country, rating, duration, listed_in
# FROM netflix.content;

# %% [markdown]
# ### B.

# %% [markdown]
# SELECT id_content, title_production, genre, runtime, imdb_Score
# FROM netflix.production;

# %% [markdown]
# ### C.

# %% [markdown]
# SELECT id_content, type, title_content, director, cast, rating, duration, listed_in
# FROM netflix.content
# WHERE country LIKE '%Argentina%';

# %% [markdown]
# ### D.

# %% [markdown]
# SELECT id_production, title_production, genre, language, imdb_score
# FROM netflix.production
# WHERE imdb_score>7.5
# ORDER BY imdb_score DESC;

# %% [markdown]
# ### E.

# %% [markdown]
# SELECT id_content, type, title_content, listed_in
# FROM netflix.content
# WHERE rating IN('TV-G','G');

# %% [markdown]
# ### F.

# %% [markdown]
# SELECT id_production, title_production, genre
# FROM netflix.production
# WHERE runtime BETWEEN 60 AND 105;

# %% [markdown]
# ### G.

# %% [markdown]
# SELECT type, rating, COUNT(*) AS titulo
# FROM netflix.content
# GROUP BY rating, type
# ORDER BY type ASC, rating ASC;

# %% [markdown]
# ### H.

# %% [markdown]
# SELECT language, COUNT(*) AS cantidad_peliculas
# FROM netflix.production
# GROUP BY language
# HAVING language IN('Portuguese','French','German','Italian','Spanish')
# ORDER BY cantidad_peliculas DESC;
